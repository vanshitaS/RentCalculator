# %%
#inputs we need from user
#total rent
#total food ordered for snacking
#electricity unit speed
#charge per unit
##OUTPUT
#Total amount you have to pay is

# %%
rent = int(input("Enter your Hostel or flat rent ="))
food = int(input("Enter the amount of food ordered ="))
electricity_spend = int(input("Enter the total of electricity spend:"))
charge_per_unit = int(input("Enter the electricity charge per unit ="))
persons = int(input("Enter the number of person living in room or flat ="))
total_bill = electricity_spend * charge_per_unit
output = (food + rent + total_bill) //persons
print("Each person will pay =",output)
